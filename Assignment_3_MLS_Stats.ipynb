# %% [markdown]
# <a href="https://colab.research.google.com/github/Atarazona11/INST-414/blob/main/Assignment_3_MLS_Stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import warnings
warnings.filterwarnings("ignore")

sns.set_theme(style='darkgrid')

# %%
# Want to import the file from my downloads
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-68ce9e7f-097c-459b-844f-660feb002eb8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-68ce9e7f-097c-459b-844f-660feb002eb8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving epl2020.csv to epl2020 (1).csv

# %%
# Open the CSV file to see how it looks.
df = pd.read_csv('epl2020.csv')

df.head()
# Out:
#    Unnamed: 0 h_a        xG       xGA      npxG     npxGA  deep  deep_allowed  \
# 0           1   h  2.234560  0.842407  2.234560  0.842407    11             5
# 1           2   a  0.842407  2.234560  0.842407  2.234560     5            11
# 2           3   a  3.183770  1.200300  2.422640  1.200300     9             1
# 3           4   h  1.200300  3.183770  1.200300  2.422640     1             9
# 4           5   h  1.340990  1.598640  1.340990  1.598640     4             6
#
#    scored  missed  ...  AF.x AC.x AY.x  AR.x  B365H.x  B365D.x  B365A.x  \
# 0       4       1  ...     9    2    2     0     1.14     10.0    19.00
# 1       1       4  ...     9    2    2     0     1.14     10.0    19.00
# 2       5       0  ...    13    1    2     0    12.00      6.5     1.22
# 3       0       5  ...    13    1    2     0    12.00      6.5     1.22
# 4       1       1  ...    19    4    1     0     1.95      3.6     3.60
#
#    HtrgPerc  AtrgPerc  matchDay
# ...

# %%
df = df.sort_values(by='Unnamed: 0').reset_index(drop=True)
df.head()
# Out:
#    Unnamed: 0 h_a        xG       xGA      npxG     npxGA  deep  deep_allowed  \
# 0           1   h  2.234560  0.842407  2.234560  0.842407    11             5
# 1           2   a  0.842407  2.234560  0.842407  2.234560     5            11
# 2           3   a  3.183770  1.200300  2.422640  1.200300     9             1
# 3           4   h  1.200300  3.183770  1.200300  2.422640     1             9
# 4           5   h  1.340990  1.598640  1.340990  1.598640     4             6
#
#    scored  missed  ...  AF.x AC.x AY.x  AR.x  B365H.x  B365D.x  B365A.x  \
# 0       4       1  ...     9    2    2     0     1.14     10.0    19.00
# 1       1       4  ...     9    2    2     0     1.14     10.0    19.00
# 2       5       0  ...    13    1    2     0    12.00      6.5     1.22
# 3       0       5  ...    13    1    2     0    12.00      6.5     1.22
# 4       1       1  ...    19    4    1     0     1.95      3.6     3.60
#
#    HtrgPerc  AtrgPerc  matchDay
# ...

# %%
# last row of data for this Kaggle Database
# Wanted to figure which one was the last row
df.iloc[575]
# Out:
# Unnamed: 0                      576
# h_a                               h
# xG                          2.41239
# xGA                        0.672448
# npxG                        1.65122
# npxGA                      0.672448
# deep                              8
# deep_allowed                      2
# scored                            4
# missed                            0
# xpts                          2.595
# result                            w
# date            2020-03-09 20:00:00
# wins                              1
# draws                             0
# loses                             0
# pts                               3
# npxGD                      0.978772
# teamId                    Leicester
# ppda_cal                    5.37931
# allowed_ppda              13.217391
# matchtime                        20
# tot_points                       53
# round                            29
# tot_goal                         58
# tot_con                          28
# ...

# %%
df = pd.read_csv('epl2020.csv')

df = df.sort_values(by='Unnamed: 0').reset_index(drop=True)

team_info = df._get_numeric_data()


team_info
# Out:
#      Unnamed: 0        xG       xGA      npxG     npxGA  deep  deep_allowed  \
# 0             1  2.234560  0.842407  2.234560  0.842407    11             5
# 1             2  0.842407  2.234560  0.842407  2.234560     5            11
# 2             3  3.183770  1.200300  2.422640  1.200300     9             1
# 3             4  1.200300  3.183770  1.200300  2.422640     1             9
# 4             5  1.340990  1.598640  1.340990  1.598640     4             6
# ..          ...       ...       ...       ...       ...   ...           ...
# 571         572  0.445922  2.028830  0.445922  2.028830     3             9
# 572         573  0.585469  1.738900  0.585469  1.738900     2             3
# 573         574  1.738900  0.585469  1.738900  0.585469     3             2
# 574         575  0.672448  2.412390  0.672448  1.651220     2             8
# 575         576  2.412390  0.672448  1.651220  0.672448     8             2
#
# ...

# %%
manu_tie_info = [team_info.iloc[452]]

# %%
from sklearn.metrics import pairwise_distances

similarity_score = pairwise_distances(manc_win_info, team_info)

# %%
team_name = df["teamId"].to_list()

similarity_list = similarity_score.tolist()


flat_similarity_list = []
for sublist in similarity_list :
  for item in sublist:
   flat_similarity_list.append(item)
flat_similarity_list

# %%
team_name = df["teamId"].to_list()

# %%
dictionary = dict(zip(team_name, flat_similarity_list))
print(dictionary)
# Out:
# {'Liverpool': 390.737966341475, 'Norwich': 390.9754487457722, 'Man City': 402.81545768249117, 'West Ham': 394.7006116443191, 'Bournemouth': 385.400627918195, 'Brighton': 387.06920861621984, 'Burnley': 396.32445191286064, 'Crystal Palace': 387.73209546048304, 'Everton': 400.4808867833359, 'Sheffield United': 390.39882751464194, 'Southampton': 393.3284101816223, 'Watford': 393.1728479627764, 'Aston Villa': 404.12191410126366, 'Tottenham': 398.12953704876463, 'Arsenal': 385.8521670203671, 'Leicester': 404.7185590411499, 'Newcastle United': 388.98386498680367, 'Wolves': 395.7241139219808, 'Chelsea': 399.5524037210989, 'Man Utd': 401.3774192732359}

# %%
sorted_dict = dict( sorted(dictionary.items(),
                           key=lambda item: item[1],
                           reverse=False))

dict_items = sorted_dict.items()

five_most_similar = list(dict_items)[:5]
for key,value in five_most_similar:
  print(key , value)
# Out:
# Bournemouth 385.400627918195
# Arsenal 385.8521670203671
# Brighton 387.06920861621984
# Crystal Palace 387.73209546048304
# Newcastle United 388.98386498680367

# %%
team_info.iloc[56]
